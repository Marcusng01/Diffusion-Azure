# %% [markdown]
# # 🤗 Training with Diffusers
#
# In recent months, it has become clear that diffusion models have taken the throne as the state-of-the-art generative models. Here, we will use Hugging Face's brand new [Diffusers](https://github.com/huggingface/diffusers) library to train a simple diffusion model.
#
# To train the diffusion model, you may use the Ukiyo_e images that comes along with the repository or download more art images from [this repository](https://github.com/cs-chan/ArtGAN/blob/master/WikiArt%20Dataset/README.md) or this [Google Drive](https://drive.google.com/file/d/1vTChp3nU5GQeLkPwotrybpUGUXj12BTK/view). Do remember to change any related directories to the directory in which you have downloaded the images to.

# %% [markdown]
# ## Installing the dependencies
#
# This notebook leverages the [🤗 Datasets](https://huggingface.co/docs/datasets/index) library to load and preprocess image datasets and the [🤗 Accelerate](https://huggingface.co/docs/accelerate/index) library to simplify training on any number of GPUs, with features like automatic gradient accumulation and tensorboard logging. Let's install them here:

# %%
# %%capture
# %pip install diffusers[training]==0.11.1

# %% [markdown]
# If you are missing dependencies, please run this line of code to download them, otherwise ignore the next cell. <br>
# If after running the cell, and you are still missing dependencies, please add the command %pip install \<name of the missing dependency\>

# %%
# %pip install -r dependencies.txt
# Out:
# Requirement already satisfied: absl-py==1.4.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 1)) (1.4.0)
# Requirement already satisfied: accelerate==0.22.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 2)) (0.22.0)
# Requirement already satisfied: adal==1.2.7 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 3)) (1.2.7)
# Requirement already satisfied: adlfs==2023.9.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 4)) (2023.9.0)
# Requirement already satisfied: aiohttp==3.8.5 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 5)) (3.8.5)
# Requirement already satisfied: aiosignal==1.3.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 6)) (1.3.1)
# Requirement already satisfied: altair==4.2.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 7)) (4.2.2)
# Requirement already satisfied: anyio==3.7.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 8)) (3.7.0)
# Requirement already satisfied: argcomplete==2.1.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 9)) (2.1.2)
# Requirement already satisfied: argon2-cffi==21.3.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 10)) (21.3.0)
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 11)) (21.2.0)
# Requirement already satisfied: arrow==1.2.3 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 12)) (1.2.3)
# Requirement already satisfied: asttokens==2.2.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 13)) (2.2.1)
# Requirement already satisfied: astunparse==1.6.3 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 14)) (1.6.3)
# Requirement already satisfied: async-timeout==4.0.3 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 15)) (4.0.3)
# Requirement already satisfied: attrs==22.2.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 16)) (22.2.0)
# Requirement already satisfied: autopep8==2.0.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 17)) (2.0.2)
# Requirement already satisfied: azure-common==1.1.28 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 18)) (1.1.28)
# Requirement already satisfied: azure-core==1.29.4 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 19)) (1.29.4)
# Requirement already satisfied: azure-datalake-store==0.0.53 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 20)) (0.0.53)
# Requirement already satisfied: azure-graphrbac==0.61.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 21)) (0.61.1)
# Requirement already satisfied: azure-identity==1.14.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 22)) (1.14.0)
# Requirement already satisfied: azure-mgmt-authorization==3.0.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 23)) (3.0.0)
# Requirement already satisfied: azure-mgmt-containerregistry==10.1.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 24)) (10.1.0)
# Requirement already satisfied: azure-mgmt-core==1.4.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 25)) (1.4.0)
# Requirement already satisfied: azure-mgmt-keyvault==10.2.3 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 26)) (10.2.3)
# Requirement already satisfied: azure-mgmt-network==21.0.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 27)) (21.0.1)
# Requirement already satisfied: azure-mgmt-resource==22.0.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 28)) (22.0.0)
# Requirement already satisfied: azure-mgmt-storage==21.0.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 29)) (21.0.0)
# Requirement already satisfied: azure-storage-blob==12.18.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 30)) (12.18.1)
# Requirement already satisfied: azureml==0.2.7 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 31)) (0.2.7)
# Requirement already satisfied: azureml-core==1.53.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 32)) (1.53.0)
# Requirement already satisfied: azureml-dataprep==4.12.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 33)) (4.12.1)
# Requirement already satisfied: azureml-dataprep-native==38.0.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 34)) (38.0.0)
# Requirement already satisfied: azureml-dataprep-rslex==2.19.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 35)) (2.19.2)
# Requirement already satisfied: backcall==0.2.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 36)) (0.2.0)
# Requirement already satisfied: backports.tempfile==1.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 37)) (1.0)
# Requirement already satisfied: backports.weakref==1.0.post1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 38)) (1.0.post1)
# Requirement already satisfied: bcrypt==4.0.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 39)) (4.0.1)
# Requirement already satisfied: beautifulsoup4==4.12.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 40)) (4.12.2)
# Requirement already satisfied: bleach==6.0.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 41)) (6.0.0)
# Requirement already satisfied: blinker==1.5 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 42)) (1.5)
# Requirement already satisfied: cachetools==5.3.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 43)) (5.3.0)
# Requirement already satisfied: certifi==2022.12.7 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 44)) (2022.12.7)
# Requirement already satisfied: cffi==1.15.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 45)) (1.15.1)
# Requirement already satisfied: charset-normalizer==3.1.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 46)) (3.1.0)
# Requirement already satisfied: click==8.1.3 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 47)) (8.1.3)
# Requirement already satisfied: cloudpickle==2.2.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 48)) (2.2.1)
# Requirement already satisfied: colorama==0.4.6 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 49)) (0.4.6)
# Requirement already satisfied: comm==0.1.3 in c:\users\user\appdata\roaming\python\python311\site-packages (from -r dependencies.txt (line 50)) (0.1.3)
# Requirement already satisfied: contextlib2==21.6.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 51)) (21.6.0)
# Requirement already satisfied: contourpy==1.0.7 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 52)) (1.0.7)
# Requirement already satisfied: cryptography==41.0.3 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 53)) (41.0.3)
# Requirement already satisfied: cycler==0.11.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 54)) (0.11.0)
# Collecting datasets==2.6.1 (from -r dependencies.txt (line 55))
#   Using cached datasets-2.6.1-py3-none-any.whl (441 kB)
# Requirement already satisfied: debugpy==1.6.6 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 56)) (1.6.6)
# Requirement already satisfied: decorator==5.1.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 57)) (5.1.1)
# Requirement already satisfied: defusedxml==0.7.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 58)) (0.7.1)
# Requirement already satisfied: diffusers==0.11.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 59)) (0.11.1)
# Requirement already satisfied: dill==0.3.7 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 60)) (0.3.7)
# Requirement already satisfied: distro==1.8.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 61)) (1.8.0)
# Requirement already satisfied: docker==6.1.3 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 62)) (6.1.3)
# Requirement already satisfied: dotnetcore2==3.1.23 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 63)) (3.1.23)
# Requirement already satisfied: entrypoints==0.4 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 64)) (0.4)
# Requirement already satisfied: et-xmlfile==1.1.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 65)) (1.1.0)
# Requirement already satisfied: executing==1.2.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 66)) (1.2.0)
# Requirement already satisfied: fastjsonschema==2.17.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 67)) (2.17.1)
# Requirement already satisfied: filelock==3.12.4 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 68)) (3.12.4)
# Requirement already satisfied: flatbuffers==23.5.26 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 69)) (23.5.26)
# Requirement already satisfied: fonttools==4.39.3 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 70)) (4.39.3)
# Requirement already satisfied: fqdn==1.5.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 71)) (1.5.1)
# Requirement already satisfied: frozenlist==1.4.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 72)) (1.4.0)
# Requirement already satisfied: fsspec==2023.6.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 73)) (2023.6.0)
# Requirement already satisfied: gast==0.4.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 74)) (0.4.0)
# Requirement already satisfied: gitdb==4.0.10 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 75)) (4.0.10)
# Requirement already satisfied: GitPython==3.1.31 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 76)) (3.1.31)
# Requirement already satisfied: google-auth==2.20.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 77)) (2.20.0)
# Requirement already satisfied: google-auth-oauthlib==1.0.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 78)) (1.0.0)
# Requirement already satisfied: google-pasta==0.2.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 79)) (0.2.0)
# Requirement already satisfied: grpcio==1.56.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 80)) (1.56.0)
# Requirement already satisfied: h5py==3.9.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 81)) (3.9.0)
# Requirement already satisfied: huggingface-hub==0.17.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 82)) (0.17.1)
# Requirement already satisfied: humanfriendly==10.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 83)) (10.0)
# Requirement already satisfied: idna==3.4 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 84)) (3.4)
# Requirement already satisfied: importlib-metadata==6.1.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 85)) (6.1.0)
# Requirement already satisfied: install==1.3.5 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 86)) (1.3.5)
# Requirement already satisfied: ipykernel==6.22.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 87)) (6.22.0)
# Requirement already satisfied: ipython==8.12.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 88)) (8.12.0)
# Requirement already satisfied: ipython-genutils==0.2.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 89)) (0.2.0)
# Requirement already satisfied: ipywidgets==8.0.6 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 90)) (8.0.6)
# Requirement already satisfied: isodate==0.6.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 91)) (0.6.1)
# Requirement already satisfied: isoduration==20.11.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 92)) (20.11.0)
# Requirement already satisfied: jax==0.4.13 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 93)) (0.4.13)
# Requirement already satisfied: jedi==0.18.2 in c:\users\user\appdata\roaming\python\python311\site-packages (from -r dependencies.txt (line 94)) (0.18.2)
# Requirement already satisfied: jeepney==0.8.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 95)) (0.8.0)
# Requirement already satisfied: Jinja2==3.1.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 96)) (3.1.2)
# Requirement already satisfied: jmespath==1.0.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 97)) (1.0.1)
# Requirement already satisfied: joblib==1.2.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 98)) (1.2.0)
# Requirement already satisfied: jsonpickle==3.0.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 99)) (3.0.2)
# Requirement already satisfied: jsonpointer==2.4 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 100)) (2.4)
# Requirement already satisfied: jsonschema==4.17.3 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 101)) (4.17.3)
# Requirement already satisfied: jupyter==1.0.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 102)) (1.0.0)
# Requirement already satisfied: jupyter-console==6.6.3 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 103)) (6.6.3)
# Requirement already satisfied: jupyter-events==0.6.3 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 104)) (0.6.3)
# Requirement already satisfied: jupyter_client==8.1.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 105)) (8.1.0)
# Requirement already satisfied: jupyter_core==5.3.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from -r dependencies.txt (line 106)) (5.3.0)
# Requirement already satisfied: jupyter_server==2.7.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 107)) (2.7.0)
# Requirement already satisfied: jupyter_server_terminals==0.4.4 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 108)) (0.4.4)
# Requirement already satisfied: jupyterlab-pygments==0.2.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 109)) (0.2.2)
# Requirement already satisfied: jupyterlab-widgets==3.0.7 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 110)) (3.0.7)
# Requirement already satisfied: keras==2.12.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 111)) (2.12.0)
# Requirement already satisfied: keras-tuner==1.3.5 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 112)) (1.3.5)
# Requirement already satisfied: kiwisolver==1.4.4 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 113)) (1.4.4)
# Requirement already satisfied: knack==0.10.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 114)) (0.10.1)
# Requirement already satisfied: kt-legacy==1.0.5 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 115)) (1.0.5)
# Requirement already satisfied: libclang==16.0.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 116)) (16.0.0)
# Requirement already satisfied: lxml==4.9.3 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 117)) (4.9.3)
# Requirement already satisfied: Markdown==3.4.3 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 118)) (3.4.3)
# Requirement already satisfied: markdown-it-py==2.2.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 119)) (2.2.0)
# Requirement already satisfied: MarkupSafe==2.1.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 120)) (2.1.2)
# Requirement already satisfied: matplotlib==3.7.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 121)) (3.7.1)
# Requirement already satisfied: matplotlib-inline==0.1.6 in c:\users\user\appdata\roaming\python\python311\site-packages (from -r dependencies.txt (line 122)) (0.1.6)
# Requirement already satisfied: mdurl==0.1.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 123)) (0.1.2)
# Requirement already satisfied: mistune==3.0.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 124)) (3.0.1)
# Requirement already satisfied: ml-dtypes==0.2.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 125)) (0.2.0)
# Requirement already satisfied: modelcards==0.1.6 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 126)) (0.1.6)
# Requirement already satisfied: mpmath==1.3.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 127)) (1.3.0)
# Requirement already satisfied: msal==1.23.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 128)) (1.23.0)
# Requirement already satisfied: msal-extensions==1.0.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 129)) (1.0.0)
# Requirement already satisfied: msrest==0.7.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 130)) (0.7.1)
# Requirement already satisfied: msrestazure==0.6.4 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 131)) (0.6.4)
# Requirement already satisfied: multidict==6.0.4 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 132)) (6.0.4)
# Requirement already satisfied: multiprocess==0.70.15 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 133)) (0.70.15)
# Requirement already satisfied: nbclassic==1.0.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 134)) (1.0.0)
# Requirement already satisfied: nbclient==0.8.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 135)) (0.8.0)
# Requirement already satisfied: nbconvert==7.6.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 136)) (7.6.0)
# Requirement already satisfied: nbformat==5.9.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 137)) (5.9.0)
# Requirement already satisfied: ndg-httpsclient==0.5.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 138)) (0.5.1)
# Requirement already satisfied: nest-asyncio==1.5.6 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 139)) (1.5.6)
# Requirement already satisfied: networkx==3.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 140)) (3.1)
# Requirement already satisfied: notebook==6.5.4 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 141)) (6.5.4)
# Requirement already satisfied: notebook_shim==0.2.3 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 142)) (0.2.3)
# Requirement already satisfied: numpy==1.23.5 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 143)) (1.23.5)
# Requirement already satisfied: oauthlib==3.2.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 144)) (3.2.2)
# Requirement already satisfied: odfpy==1.4.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 145)) (1.4.1)
# Requirement already satisfied: openpyxl==3.1.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 146)) (3.1.2)
# Requirement already satisfied: opt-einsum==3.3.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 147)) (3.3.0)
# Requirement already satisfied: overrides==7.3.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 148)) (7.3.1)
# Requirement already satisfied: packaging==23.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 149)) (23.0)
# Requirement already satisfied: pandas==1.5.3 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 150)) (1.5.3)
# Requirement already satisfied: pandocfilters==1.5.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 151)) (1.5.0)
# Requirement already satisfied: paramiko==3.3.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 152)) (3.3.1)
# Requirement already satisfied: parso==0.8.3 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 153)) (0.8.3)
# Requirement already satisfied: pathspec==0.11.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 154)) (0.11.2)
# Requirement already satisfied: pickleshare==0.7.5 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 155)) (0.7.5)
# Requirement already satisfied: Pillow==9.4.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 156)) (9.4.0)
# Requirement already satisfied: pkginfo==1.9.6 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 157)) (1.9.6)
# Requirement already satisfied: platformdirs==3.2.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 158)) (3.2.0)
# Requirement already satisfied: portalocker==2.7.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 159)) (2.7.0)
# Requirement already satisfied: prometheus-client==0.17.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 160)) (0.17.0)
# Requirement already satisfied: prompt-toolkit==3.0.38 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 161)) (3.0.38)
# Requirement already satisfied: protobuf==3.20.3 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 162)) (3.20.3)
# Requirement already satisfied: psutil==5.9.4 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 163)) (5.9.4)
# Requirement already satisfied: pure-eval==0.2.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 164)) (0.2.2)
# Requirement already satisfied: pyarrow==11.0.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 165)) (11.0.0)
# Requirement already satisfied: pyasn1==0.5.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 166)) (0.5.0)
# Requirement already satisfied: pyasn1-modules==0.3.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 167)) (0.3.0)
# Requirement already satisfied: pycodestyle==2.10.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 168)) (2.10.0)
# Requirement already satisfied: pycparser==2.21 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 169)) (2.21)
# Requirement already satisfied: pydeck==0.8.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 170)) (0.8.0)
# Requirement already satisfied: Pygments==2.14.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 171)) (2.14.0)
# Requirement already satisfied: PyJWT==2.8.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 172)) (2.8.0)
# Requirement already satisfied: Pympler==1.0.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 173)) (1.0.1)
# Requirement already satisfied: PyNaCl==1.5.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 174)) (1.5.0)
# Requirement already satisfied: pyOpenSSL==23.2.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 175)) (23.2.0)
# Requirement already satisfied: pyparsing==3.0.9 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 176)) (3.0.9)
# Requirement already satisfied: pyreadline3==3.4.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 177)) (3.4.1)
# Requirement already satisfied: pyrsistent==0.19.3 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 178)) (0.19.3)
# Requirement already satisfied: PySocks==1.7.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 179)) (1.7.1)
# Requirement already satisfied: python-dateutil==2.8.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 180)) (2.8.2)
# Requirement already satisfied: python-docx==0.8.11 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 181)) (0.8.11)
# Requirement already satisfied: python-json-logger==2.0.7 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 182)) (2.0.7)
# Requirement already satisfied: pytz==2023.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 183)) (2023.2)
# Requirement already satisfied: pytz-deprecation-shim==0.1.0.post0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 184)) (0.1.0.post0)
# Requirement already satisfied: pywin32==306 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 185)) (306)
# Requirement already satisfied: pywinpty==2.0.10 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 186)) (2.0.10)
# Requirement already satisfied: pyxlsb==1.0.10 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 187)) (1.0.10)
# Requirement already satisfied: PyYAML==6.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 188)) (6.0)
# Requirement already satisfied: pyzmq==25.0.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 189)) (25.0.2)
# Requirement already satisfied: qtconsole==5.4.3 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 190)) (5.4.3)
# Requirement already satisfied: QtPy==2.3.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 191)) (2.3.1)
# Requirement already satisfied: regex==2023.8.8 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 192)) (2023.8.8)
# Requirement already satisfied: requests==2.28.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 193)) (2.28.2)
# Requirement already satisfied: requests-oauthlib==1.3.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 194)) (1.3.1)
# Requirement already satisfied: rfc3339-validator==0.1.4 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 195)) (0.1.4)
# Requirement already satisfied: rfc3986-validator==0.1.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 196)) (0.1.1)
# Requirement already satisfied: rich==13.3.3 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 197)) (13.3.3)
# Requirement already satisfied: rsa==4.9 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 198)) (4.9)
# Requirement already satisfied: scikit-learn==1.2.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 199)) (1.2.2)
# Requirement already satisfied: scipy==1.10.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 200)) (1.10.1)
# Requirement already satisfied: seaborn==0.12.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 201)) (0.12.2)
# Requirement already satisfied: SecretStorage==3.3.3 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 202)) (3.3.3)
# Requirement already satisfied: semver==2.13.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 203)) (2.13.0)
# Requirement already satisfied: Send2Trash==1.8.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 204)) (1.8.2)
# Requirement already satisfied: six==1.16.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 205)) (1.16.0)
# Requirement already satisfied: smmap==5.0.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 206)) (5.0.0)
# Requirement already satisfied: sniffio==1.3.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 207)) (1.3.0)
# Requirement already satisfied: soupsieve==2.4.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 208)) (2.4.1)
# Requirement already satisfied: stack-data==0.6.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 209)) (0.6.2)
# Requirement already satisfied: streamlit==1.22.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 210)) (1.22.0)
# Requirement already satisfied: sympy==1.12 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 211)) (1.12)
# Requirement already satisfied: tabulate==0.9.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 212)) (0.9.0)
# Requirement already satisfied: tenacity==8.2.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 213)) (8.2.2)
# Requirement already satisfied: tensorboard==2.12.3 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 214)) (2.12.3)
# Requirement already satisfied: tensorboard-data-server==0.7.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 215)) (0.7.1)
# Requirement already satisfied: tensorflow==2.12.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 216)) (2.12.0)
# Requirement already satisfied: tensorflow-estimator==2.12.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 217)) (2.12.0)
# Requirement already satisfied: tensorflow-intel==2.12.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 218)) (2.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.31.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 219)) (0.31.0)
# Requirement already satisfied: termcolor==2.3.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 220)) (2.3.0)
# Requirement already satisfied: terminado==0.17.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 221)) (0.17.1)
# Requirement already satisfied: threadpoolctl==3.1.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 222)) (3.1.0)
# Requirement already satisfied: tinycss2==1.2.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 223)) (1.2.1)
# Requirement already satisfied: toml==0.10.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 224)) (0.10.2)
# Requirement already satisfied: tomli==2.0.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 225)) (2.0.1)
# Requirement already satisfied: toolz==0.12.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 226)) (0.12.0)
# Requirement already satisfied: torch==2.0.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 227)) (2.0.1)
# Requirement already satisfied: torchvision==0.15.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 228)) (0.15.2)
# Requirement already satisfied: tornado==6.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 229)) (6.2)
# Requirement already satisfied: tqdm==4.66.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 230)) (4.66.1)
# Requirement already satisfied: traitlets==5.9.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 231)) (5.9.0)
# Requirement already satisfied: typing_extensions==4.7.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 232)) (4.7.1)
# Requirement already satisfied: tzdata==2023.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 233)) (2023.2)
# Requirement already satisfied: tzlocal==4.3 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 234)) (4.3)
# Requirement already satisfied: uri-template==1.3.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 235)) (1.3.0)
# Requirement already satisfied: urllib3==1.26.15 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 236)) (1.26.15)
# Requirement already satisfied: validators==0.20.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 237)) (0.20.0)
# Requirement already satisfied: watchdog==3.0.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 238)) (3.0.0)
# Requirement already satisfied: wcwidth==0.2.6 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 239)) (0.2.6)
# Requirement already satisfied: webcolors==1.13 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 240)) (1.13)
# Requirement already satisfied: webencodings==0.5.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 241)) (0.5.1)
# Requirement already satisfied: websocket-client==1.6.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 242)) (1.6.1)
# Requirement already satisfied: Werkzeug==2.3.6 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 243)) (2.3.6)
# Requirement already satisfied: widgetsnbextension==4.0.7 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 244)) (4.0.7)
# Requirement already satisfied: wrapt==1.14.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 245)) (1.14.1)
# Requirement already satisfied: xlrd==2.0.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 246)) (2.0.1)
# Requirement already satisfied: XlsxWriter==3.1.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 247)) (3.1.0)
# Requirement already satisfied: xxhash==3.3.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 248)) (3.3.0)
# Requirement already satisfied: yarl==1.9.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 249)) (1.9.2)
# Requirement already satisfied: zipp==3.15.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from -r dependencies.txt (line 250)) (3.15.0)
# INFO: pip is looking at multiple versions of adlfs to determine which version is compatible with other requirements. This could take a while.
#
# The conflict is caused by:
#     The user requested fsspec==2023.6.0
#     adlfs 2023.9.0 depends on fsspec>=2023.9.0
#
# To fix this you could try to:
# 1. loosen the range of package versions you've specified
# 2. remove package versions to allow pip attempt to solve the dependency conflict
#
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Cannot install adlfs==2023.9.0 and fsspec==2023.6.0 because these package versions have conflicting dependencies.
# ERROR: ResolutionImpossible: for help visit https://pip.pypa.io/en/latest/topics/dependency-resolution/#dealing-with-dependency-conflicts
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# To be able to share your model with the community, there are a few more steps to follow.|
#
# First you have to store your authentication token from the Hugging Face website (sign up [here](https://huggingface.co/join) if you haven't already!) then execute the following cell and input your **write** token:

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# Then you need to install Git-LFS to upload your model checkpoints. However, I have disabled the ability to push the model to the Hugging Face hub in the TrainingConfig Class as I would want to store the model locally. However, feel free to experiment.

# %%
# %%capture
# %sudo apt -qq install git-lfs
# %git config --global credential.helper store

# %% [markdown]
# ## Config
#
# For convenience, we define a configuration grouping all the training hyperparameters. This would be similar to the arguments used for a [training script](https://github.com/huggingface/diffusers/tree/main/examples).
# Here we choose reasonable defaults for hyperparameters like `num_epochs`, `learning_rate`, `lr_warmup_steps`, but feel free to adjust them if you train on your own dataset. For example, `num_epochs` can be increased to 100 for better visual quality.

# %%
from dataclasses import dataclass

@dataclass
class TrainingConfig:
    image_size = 128  # the generated image resolution
    train_batch_size = 16
    eval_batch_size = 16  # how many images to sample during evaluation
    num_epochs = 50
    gradient_accumulation_steps = 1
    learning_rate = 1e-4
    lr_warmup_steps = 500
    save_image_epochs = 10
    save_model_epochs = 30
    mixed_precision = 'fp16'  # `no` for float32, `fp16` for automatic mixed precision
    output_dir = 'ddpm-butterflies-128'  # the model namy locally and on the HF Hub

    push_to_hub = False  # whether to upload the saved model to the HF Hub
    hub_private_repo = False
    overwrite_output_dir = True  # overwrite the old model when re-running the notebook
    seed = 0

config = TrainingConfig()

# %% [markdown]
# ## Loading the dataset
#
# We will use the [🤗 Datasets](https://github.com/huggingface/datasets) library to download our image dataset.

# %% [markdown]
# Note that the load_dataset() function will split the images based on specific keywords, namely "test", "train" and "valid". So to prevent the automatic splitting of images, we need to change the name of any image file by removing said keywords

# %%
import os
import re

# Define the directory path
directory_path = r'./Ukiyo_e' #Change the data_dir to the location where your images are stored

# List of words to remove from filenames
words_to_remove = ["train", "test", "valid"]

# Function to rename files
def rename_files(directory):
    for foldername, subfolders, filenames in os.walk(directory):
        for filename in filenames:
            # Use regular expressions to replace "train," "test," and "valid" in filenames
            new_filename = re.sub(r'(?i)(train|test|valid)', '', filename)
            
            # Check if the filename has changed
            if new_filename != filename:
                old_path = os.path.join(foldername, filename)
                new_path = os.path.join(foldername, new_filename)
                # Rename the file
                os.rename(old_path, new_path)
                print(f'Renamed: {filename} -> {new_filename}')

# Call the function to rename files
rename_files(directory_path)

# %% [markdown]
# I suggest you to use  local [ImageFolder](https://huggingface.co/docs/datasets/v2.0.0/en/image_process#imagefolder) as shown below. However, there is an alternate [Butterflies dataset](https://huggingface.co/datasets/huggan/smithsonian_butterflies_subset) hosted remotely that you may load via the comments below. The trained model will be able to produce butterflies instead of the art that you have downloaded locally.

# %%
from datasets import load_dataset

# config.dataset_name = "huggan/smithsonian_butterflies_subset"
# dataset = load_dataset(config.dataset_name, split="train")

# Feel free to try other datasets from https://hf.co/huggan/ too!
# Here's is a dataset of flower photos:
# config.dataset_name = "huggan/flowers-102-categories"
# dataset = load_dataset(config.dataset_name, split="train")

# Or just load images from a local folder!
config.dataset_name = "imagefolder"
dataset = load_dataset(config.dataset_name, data_dir=directory_path, split="train")
# Out:
# Resolving data files:   0%|          | 0/1167 [00:00<?, ?it/s]

# %% [markdown]
# The dataset contains several extra `features` (columns), but the one that we're interested in is `image`:

# %%
dataset
# Out:
# Dataset({
#     features: ['image'],
#     num_rows: 1167
# })

# %% [markdown]
# Since the [`Image`](https://huggingface.co/docs/datasets/image_process#image-datasets) feature loads the images with PIL, we can easily look at a few examples:

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 4, figsize=(16, 4))
for i, image in enumerate(dataset[:4]["image"]):
    axs[i].imshow(image)
    axs[i].set_axis_off()
fig.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10124\3278871621.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# The images in the dataset are all different, so we need to preprocess them first:
# * `Resize` makes the images conform to a square resolution of `config.image_size`
# * `RandomHorizontalFlip` augments the dataset by randomly mirroring the images.
# * `Normalize` is important to rescale the pixel values into a `[-1, 1]` range (which our model will expect).

# %%
from torchvision import transforms

preprocess = transforms.Compose(
    [
        transforms.Resize((config.image_size, config.image_size)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.5], [0.5]),
    ]
)

# %% [markdown]
# 🤗 Datasets offer a handy `set_transform()` method to apply the image transformations on the fly during training:

# %%
def transform(examples):
    images = [preprocess(image.convert("RGB")) for image in examples["image"]]
    return {"images": images}

dataset.set_transform(transform)

# %% [markdown]
# Let's see what they look like now

# %%
fig, axs = plt.subplots(1, 4, figsize=(16, 4))
for i, image in enumerate(dataset[:4]["images"]):
    axs[i].imshow(image.permute(1, 2, 0).numpy() / 2 + 0.5)
    axs[i].set_axis_off()
fig.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10124\948138263.py:5: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# Now that all our images have the same size and are converted to tensors, we can create the dataloader we will use for training.

# %%
import torch

train_dataloader = torch.utils.data.DataLoader(dataset, batch_size=config.train_batch_size, shuffle=True)

# %% [markdown]
# ## Defining the diffusion model
#
# Here we set up our diffusion model. Diffusion models are neural networks that are trained to predict slightly less noisy images from a noisy input. At inference, they can be used to iteratively transform a random noise to generate an image:
#
# <p align="center">
#     <img src="https://user-images.githubusercontent.com/10695622/174349667-04e9e485-793b-429a-affe-096e8199ad5b.png" width="800"/>
#     <br>
#     <em> Figure from DDPM paper (https://arxiv.org/abs/2006.11239). </em>
# <p>
#
# Don't worry too much about the math if you're not familiar with it, the import part to remember is that our model corresponds to the arrow $p_{\theta}(x_{t-1}|x_{t})$ (which is a fancy way of saying: predict a slightly less noisy image).
#
# The interesting part is that it's really easy to add some noise to an image, so the training can happen in a semi-supervised fashion as follows:
# 1. Take an image from the training set.
# 2. Apply to it some random noise $t$ times (this will give the $x_{t-1}$ and the $x_{t}$ in the figure above).
# 3. Give this noisy image to the model along with the value of $t$.
# 4. Compute a loss from the output of the model and the noised image $x_{t-1}$.
#
# Then we can apply gradient descent and repeat this process multiple times.

# %% [markdown]
# Most diffusion models use architectures that are some variant of a [U-net](https://arxiv.org/abs/1505.04597) and that's what we'll use here.
#
# ![](https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/unet-model.png)
#
# In a nutshell:
# - the model has the input image go through several blocks of ResNet layers which halves the image size by 2
# - then through the same number of blocks that upsample it again.
# - there are skip connections linking the features on the downample path to the corresponsding layers in the upsample path.
#
# A key feature of this model is that it predicts images of the same size as the input, which is exactly what we need here.
#
# Diffusers provides us a handy `UNet2DModel` class which creates the desired architecture in PyTorch.
#
# Let's create a U-net for our desired image size.
# Note that `down_block_types` correspond to the downsampling blocks (green on the diagram above), and `up_block_types` are the upsampling blocks (red on the diagram):

# %%
from diffusers import UNet2DModel

model = UNet2DModel(
    sample_size=config.image_size,  # the target image resolution
    in_channels=3,  # the number of input channels, 3 for RGB images
    out_channels=3,  # the number of output channels
    layers_per_block=2,  # how many ResNet layers to use per UNet block
    block_out_channels=(128, 128, 256, 256, 512, 512),  # the number of output channes for each UNet block
    down_block_types=(
        "DownBlock2D",  # a regular ResNet downsampling block
        "DownBlock2D",
        "DownBlock2D",
        "DownBlock2D",
        "AttnDownBlock2D",  # a ResNet downsampling block with spatial self-attention
        "DownBlock2D",
    ),
    up_block_types=(
        "UpBlock2D",  # a regular ResNet upsampling block
        "AttnUpBlock2D",  # a ResNet upsampling block with spatial self-attention
        "UpBlock2D",
        "UpBlock2D",
        "UpBlock2D",
        "UpBlock2D"
      ),
)

# %% [markdown]
# Let's get a sample image from our dataset and pass it into our model. We just need to add a batch dimension:

# %%
sample_image = dataset[0]['images'].unsqueeze(0)
print('Input shape:', sample_image.shape)
# Out:
# Input shape: torch.Size([1, 3, 128, 128])

# %% [markdown]
# And let's check the output is a tensor of the same exact shape:

# %%
print('Output shape:', model(sample_image, timestep=0).sample.shape)
# Out:
# Output shape: torch.Size([1, 3, 128, 128])

# %% [markdown]
# Great!
#
# Note that our model takes in the (noisy) image and also the current time-step (as we saw before in the training overview). That time-step information is converted for the model using a sinusoidal positional embedding, similar to what Transformer models often do.
#
# Now that we have our model, we just need an object to *add noise to an image*. This is done by the **schedulers** in the `diffusers` library.

# %% [markdown]
# ## Defining the noise scheduler
#
# Depending on the diffusion algorithm you want to use, the way images are noised is slightly different. That's why 🤗 Diffusers contains different scheduler classes which each define the algorithm-specific diffusion steps. Here we are going to use the `DDPMScheduler` which corresponds to the training denoising and training algorithm proposed in [Denoising Diffusion Probabilistic Models](https://arxiv.org/abs/2006.11239).

# %%
from diffusers import DDPMScheduler

noise_scheduler = DDPMScheduler(num_train_timesteps=1000)

# %% [markdown]
# Let's see how this noise scheduler works: it takes a batch of images from the trainng set (here we will reuse the batch of one image `sample_image` form before), a batch of random noise of the same shape and the timesteps for each image (which correspond to the number of times we want to apply noise to each image):

# %%
import torch
from PIL import Image

noise = torch.randn(sample_image.shape)
timesteps = torch.LongTensor([50])
noisy_image = noise_scheduler.add_noise(sample_image, noise, timesteps)

Image.fromarray(((noisy_image.permute(0, 2, 3, 1) + 1.0) * 127.5).type(torch.uint8).numpy()[0])
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %% [markdown]
# In the DDPM algorithm, the training objective of the model is then to be able to predict the noise we used in `noise_scheduler.add_noise`, so the loss at this step would be:

# %%
import torch.nn.functional as F

noise_pred = model(noisy_image, timesteps).sample
loss = F.mse_loss(noise_pred, noise)

# %% [markdown]
# ## Setting up training
#
# We have all we need to be able to train our model! Let's use a standard AdamW optimizer:

# %%
optimizer = torch.optim.AdamW(model.parameters(), lr=config.learning_rate)

# %% [markdown]
#  And a cosine learning rate schedule:

# %%
from diffusers.optimization import get_cosine_schedule_with_warmup

lr_scheduler = get_cosine_schedule_with_warmup(
    optimizer=optimizer,
    num_warmup_steps=config.lr_warmup_steps,
    num_training_steps=(len(train_dataloader) * config.num_epochs),
)

# %% [markdown]
# To evaluate our model, we use the `DDPMPipeline` which is an easy way to perform end-to-end inference. We will use this pipeline to generate a batch of sample images and save it as a grid to the disk.

# %%
from diffusers import DDPMPipeline

import math

def make_grid(images, rows, cols):
    w, h = images[0].size
    grid = Image.new('RGB', size=(cols*w, rows*h))
    for i, image in enumerate(images):
        grid.paste(image, box=(i%cols*w, i//cols*h))
    return grid

def evaluate(config, epoch, pipeline):
    # Sample some images from random noise (this is the backward diffusion process).
    # The default pipeline output type is `List[PIL.Image]`
    images = pipeline(
        batch_size = config.eval_batch_size,
        generator=torch.manual_seed(config.seed),
    ).images

    # Make a grid out of the images
    image_grid = make_grid(images, rows=4, cols=4)

    # Save the images
    test_dir = os.path.join(config.output_dir, "samples")
    os.makedirs(test_dir, exist_ok=True)
    image_grid.save(f"{test_dir}/{epoch:04d}.png")

# %% [markdown]
# With this in end, we can group all together and write our training function. This just wraps the training step we saw in the previous section in a loop, using Accelerate for easy TensorBoard logging, gradient accumulation, mixed precision training and multi-GPUs or TPU training.

# %%
from accelerate import Accelerator
from huggingface_hub import HfFolder, Repository, whoami

from tqdm.auto import tqdm
from pathlib import Path
import os

def get_full_repo_name(model_id: str, organization: str = None, token: str = None):
    if token is None:
        token = HfFolder.get_token()
    if organization is None:
        username = whoami(token)["name"]
        return f"{username}/{model_id}"
    else:
        return f"{organization}/{model_id}"

def train_loop(config, model, noise_scheduler, optimizer, train_dataloader, lr_scheduler):
    # Initialize accelerator and tensorboard logging
    accelerator = Accelerator(
        mixed_precision=config.mixed_precision,
        gradient_accumulation_steps=config.gradient_accumulation_steps,
        log_with="tensorboard",
        project_dir=os.path.join(config.output_dir, "logs")
    )
    if accelerator.is_main_process:
        if config.push_to_hub:
            repo_name = get_full_repo_name(Path(config.output_dir).name)
            repo = Repository(config.output_dir, clone_from=repo_name)
        elif config.output_dir is not None:
            os.makedirs(config.output_dir, exist_ok=True)
        accelerator.init_trackers("train_example")

    # Prepare everything
    # There is no specific order to remember, you just need to unpack the
    # objects in the same order you gave them to the prepare method.
    model, optimizer, train_dataloader, lr_scheduler = accelerator.prepare(
        model, optimizer, train_dataloader, lr_scheduler
    )

    global_step = 0

    # Now you train the model
    for epoch in range(config.num_epochs):
        progress_bar = tqdm(total=len(train_dataloader), disable=not accelerator.is_local_main_process)
        progress_bar.set_description(f"Epoch {epoch}")

        for step, batch in enumerate(train_dataloader):
            clean_images = batch['images']
            # Sample noise to add to the images
            noise = torch.randn(clean_images.shape).to(clean_images.device)
            bs = clean_images.shape[0]

            # Sample a random timestep for each image
            timesteps = torch.randint(0, noise_scheduler.config.num_train_timesteps, (bs,), device=clean_images.device).long()

            # Add noise to the clean images according to the noise magnitude at each timestep
            # (this is the forward diffusion process)
            noisy_images = noise_scheduler.add_noise(clean_images, noise, timesteps)

            with accelerator.accumulate(model):
                # Predict the noise residual
                noise_pred = model(noisy_images, timesteps, return_dict=False)[0]
                loss = F.mse_loss(noise_pred, noise)
                accelerator.backward(loss)

                accelerator.clip_grad_norm_(model.parameters(), 1.0)
                optimizer.step()
                lr_scheduler.step()
                optimizer.zero_grad()

            progress_bar.update(1)
            logs = {"loss": loss.detach().item(), "lr": lr_scheduler.get_last_lr()[0], "step": global_step}
            progress_bar.set_postfix(**logs)
            accelerator.log(logs, step=global_step)
            global_step += 1

        # After each epoch you optionally sample some demo images with evaluate() and save the model
        if accelerator.is_main_process:
            pipeline = DDPMPipeline(unet=accelerator.unwrap_model(model), scheduler=noise_scheduler)

            if (epoch + 1) % config.save_image_epochs == 0 or epoch == config.num_epochs - 1:
                evaluate(config, epoch, pipeline)

            if (epoch + 1) % config.save_model_epochs == 0 or epoch == config.num_epochs - 1:
                if config.push_to_hub:
                    repo.push_to_hub(commit_message=f"Epoch {epoch}", blocking=True)
                else:
                    pipeline.save_pretrained(config.output_dir)

# %% [markdown]
# ## Let's train!
#
# Let's launch the training (including multi-GPU training) from the notebook using Accelerate's `notebook_launcher` function:

# %%
from accelerate import notebook_launcher
args = (config, model, noise_scheduler, optimizer, train_dataloader, lr_scheduler)

notebook_launcher(train_loop, args, num_processes=1)

# %% [markdown]
# Let's have a look at the final image grid produced by the trained diffusion model:

# %%
import glob

sample_images = sorted(glob.glob(f"{config.output_dir}/samples/*.png"))
Image.open(sample_images[-1])

# %% [markdown]
# Not bad! There's room for improvement of course, so feel free to play with the hyperparameters, model definition and image augmentations 🤗
#
# If you've chosen to upload the model to the Hugging Face Hub, its repository should now look like so:
# https://huggingface.co/anton-l/ddpm-butterflies-128/tree/main
#
# If you want to dive deeper into the code, we also have more advanced training scripts with features like Exponential Moving Average of model weights here:
#
# https://github.com/huggingface/diffusers/tree/main/examples
